# %% [markdown]
# ### Foram encontrados 8 prefixos de CEP associados a mais de um estado. Alguns casos apresentam indícios claros de inconsistência, como registros de São Paulo associados a RN ou AC. Esses casos deverão ser avaliados na etapa de tratamento dos dados.

# %%
df_geolocation[filtro_ceps][
    ['geolocation_zip_code_prefix', 'geolocation_city', 'geolocation_state']
].drop_duplicates()
# Out:
#         geolocation_zip_code_prefix          geolocation_city  \
# 21728                          2116                 sao paulo
# 22193                          2116                 são paulo
# 22261                          2116                 são paulo
# 71032                          4011                 sao paulo
# 71247                          4011                 são paulo
# 72852                          4011                 sao paulo
# 430342                        21550            rio de janeiro
# 430999                        21550            rio de janeiro
# 459234                        23056            rio de janeiro
# 460406                        23056            rio de janeiro
# 792362                        72915     aguas lindas de goias
# 792394                        72915                taguatinga
# 792490                        72915     águas lindas de goiás
# 825876                        78557                     sinop
# ...

# %%
filtro_ceps = df_geolocation['geolocation_zip_code_prefix'].isin(filtro2.index)

df_geolocation[filtro_ceps]
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 21728                          2116       -23.522700       -46.587546
# 21759                          2116       -23.518459       -46.584128
# 21788                          2116       -23.518459       -46.584128
# 22060                          2116       -23.519065       -46.584610
# 22193                          2116       -23.519739       -46.585151
# ...                             ...              ...              ...
# 847871                        80630       -25.468930       -49.280779
# 847872                        80630       -25.469776       -49.273230
# 847875                        80630       -25.466519       -49.268213
# 847878                        80630       -25.461689       -49.272160
# 847897                        80630       -25.473179       -49.282526
#
#        geolocation_city geolocation_state
# 21728         sao paulo                SP
# ...

# %%
filtro = df_geolocation['geolocation_zip_code_prefix'] == 2116
df_geolocation[filtro]
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 21728                         2116       -23.522700       -46.587546
# 21759                         2116       -23.518459       -46.584128
# 21788                         2116       -23.518459       -46.584128
# 22060                         2116       -23.519065       -46.584610
# 22193                         2116       -23.519739       -46.585151
# 22261                         2116       -23.515978       -46.582170
# 22330                         2116       -23.518746       -46.583058
# 22503                         2116       -23.519065       -46.584610
# 22638                         2116       -23.522404       -46.587229
# 22740                         2116       -23.517004       -46.583043
# 22742                         2116       -23.525834       -46.589954
# 22804                         2116       -23.525239       -46.589437
# 22879                         2116       -23.518746       -46.583058
#
# ...

# %%
filtro = df_geolocation.groupby('geolocation_zip_code_prefix')['geolocation_state'].nunique()
filtro2 = filtro[filtro>1]
filtro2
# Out:
# geolocation_zip_code_prefix
# 2116     2
# 4011     2
# 21550    2
# 23056    2
# 72915    2
# 78557    2
# 79750    2
# 80630    2
# Name: geolocation_state, dtype: int64

# %%
filtro = df_geolocation.duplicated().sum()
filtro
# Out:
# np.int64(261831)

# %%
filtro = df_geolocation['geolocation_zip_code_prefix'] == 1037
df_geolocation[filtro]
# Out:
#       geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                            1037       -23.545621       -46.639292
# 14                           1037       -23.545187       -46.637855
# 31                           1037       -23.546705       -46.640336
# 169                          1037       -23.543883       -46.638075
# 178                          1037       -23.546157       -46.639885
# 236                          1037       -23.543883       -46.638075
# 283                          1037       -23.545199       -46.637916
# 417                          1037       -23.545187       -46.637855
# 420                          1037       -23.546723       -46.640281
# 433                          1037       -23.546463       -46.640145
# 513                          1037       -23.545621       -46.639292
# 533                          1037       -23.545808       -46.639602
# 677                          1037       -23.545867       -46.639685
# ...

# %%
filtro = df_geolocation['geolocation_zip_code_prefix'] == 1037
filtro.value_counts()
# Out:
# geolocation_zip_code_prefix
# False    1000137
# True          26
# Name: count, dtype: int64

# %%
df_geolocation['geolocation_zip_code_prefix'].nunique()
# Out:
# 19015

# %%
df_geolocation.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
df_geolocation.dtypes
# Out:
# geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                object
# geolocation_state               object
# dtype: object

# %%
df_geolocation.columns
# Out:
# Index(['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng',
#        'geolocation_city', 'geolocation_state'],
#       dtype='object')

# %%
df_geolocation.shape
# Out:
# (1000163, 5)

# %%
df_geolocation = pd.read_csv("../data/olist_geolocation_dataset.csv")
df_geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# ### Analisando vendedores...

# %%
filtro = df_sellers['seller_id'].duplicated().sum()
filtro
# Out:
# np.int64(0)

# %%
filtro = df_sellers['seller_city'].value_counts()
filtro
# Out:
# seller_city
# sao paulo              694
# curitiba               127
# rio de janeiro          96
# belo horizonte          68
# ribeirao preto          52
#                       ...
# taruma                   1
# s jose do rio preto      1
# domingos martins         1
# messias targino          1
# leme                     1
# Name: count, Length: 611, dtype: int64

# %%
filtro = ((df_sellers['seller_state'] == 'SP').sum())/(df_sellers['seller_state'].notna().sum())*100
filtro
# Out:
# np.float64(59.741518578352185)

# %%
df_sellers['seller_state'].value_counts()
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# RN       5
# MS       5
# MT       4
# RO       2
# SE       2
# PI       1
# AC       1
# MA       1
# AM       1
# PA       1
# Name: count, dtype: int64

# %%
df_sellers.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
df_sellers.dtypes
# Out:
# seller_id                 object
# seller_zip_code_prefix     int64
# seller_city               object
# seller_state              object
# dtype: object

# %%
df_sellers['seller_id'].nunique()
# Out:
# 3095

# %%
df_sellers.columns
# Out:
# Index(['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state'], dtype='object')

# %%
df_sellers.shape
# Out:
# (3095, 4)

# %%
df_sellers = pd.read_csv("../data/olist_sellers_dataset.csv")
df_sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Analisando as avaliações...

# %% [markdown]
# ### A proporção de comentários é maior nas avaliações de 1 estrela, sugerindo que clientes insatisfeitos tendem a registrar suas experiências por escrito com maior frequência.

# %%
filtro = ((df_reviews['review_score'] == 4) & (df_reviews['review_comment_message'].notna())).sum()/((df_reviews['review_score'] == 4).sum())*100
filtro
# Out:
# np.float64(31.219308327238533)

# %%
filtro = ((df_reviews['review_score'] == 3) & (df_reviews['review_comment_message'].notna())).sum()/((df_reviews['review_score'] == 3).sum())*100
filtro
# Out:
# np.float64(43.48942413497983)

# %%
filtro = ((df_reviews['review_score'] == 2) & (df_reviews['review_comment_message'].notna())).sum()/((df_reviews['review_score'] == 2).sum())*100
filtro
# Out:
# np.float64(68.07362741986671)

# %%
filtro = ((df_reviews['review_score'] == 5) & (df_reviews['review_comment_message'].notna())).sum()/((df_reviews['review_score'] == 5).sum())*100
filtro
# Out:
# np.float64(35.85333519397153)

# %%
filtro = ((df_reviews['review_score'] == 1) & (df_reviews['review_comment_message'].notna())).sum()/((df_reviews['review_score'] == 1).sum())*100
filtro
# Out:
# np.float64(76.54936974789915)

# %%
filtro = (df_reviews['review_score'] == 1) & df_reviews['review_comment_message'].notna()
filtro.sum()
# Out:
# np.int64(8745)

# %%
filtro = df_reviews['review_score'] == 1
filtro.sum()
# Out:
# np.int64(11424)

# %%
filtro = df_reviews['review_comment_message'].notna()
df_reviews[filtro]['review_score'].value_counts()
# Out:
# review_score
# 5    20554
# 1     8745
# 4     5976
# 3     3557
# 2     2145
# Name: count, dtype: int64

# %%
filtro = df_reviews['review_comment_message'].notna()
filtro.sum()
# Out:
# np.int64(40977)

# %%
df_reviews['review_score'].mean()
# Out:
# np.float64(4.08642062404257)

# %%
filtro = df_reviews.isna().sum()
filtro
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
df_reviews.dtypes
# Out:
# review_id                  object
# order_id                   object
# review_score                int64
# review_comment_title       object
# review_comment_message     object
# review_creation_date       object
# review_answer_timestamp    object
# dtype: object

# %%
df_reviews.columns
# Out:
# Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp'],
#       dtype='object')

# %%
filtro = df_reviews['review_score'].value_counts()
filtro
# Out:
# review_score
# 5    57328
# 4    19142
# 1    11424
# 3     8179
# 2     3151
# Name: count, dtype: int64

# %%
df_reviews.shape
# Out:
# (99224, 7)

# %%
df_reviews = pd.read_csv("../data/olist_order_reviews_dataset.csv")
df_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %% [markdown]
# ### Analisando pagamentos...

# %% [markdown]
# ### Inconsistências
#
# Primeiro, encontramos 9 valores com valor de pagamento = 0. Desses, 3 têm o tipo de pagamento como 'not_defined'. Além disso, 2 registros de cartão de crédito têm um total de 0 parcelas.

# %%
filtro = df_payments['payment_type'] == 'not_defined'
df_payments[filtro]
# Out:
#                                order_id  payment_sequential payment_type  \
# 51280  4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 57411  00b1cb0320190ca0daa2c88b35206009                   1  not_defined
# 94427  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
#
#        payment_installments  payment_value
# 51280                     1            0.0
# 57411                     1            0.0
# 94427                     1            0.0

# %%
filtro = df_payments['payment_type'].value_counts()
filtro
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %%
filtro = df_payments['order_id'] == '744bade1fcf9ff3f31d860ace076d422'
df_payments[filtro]
# Out:
#                                order_id  payment_sequential payment_type  \
# 46982  744bade1fcf9ff3f31d860ace076d422                   2  credit_card
#
#        payment_installments  payment_value
# 46982                     0          58.69

# %%
filtro = df_payments['payment_installments'] == 0
df_payments[filtro]
# Out:
#                                order_id  payment_sequential payment_type  \
# 46982  744bade1fcf9ff3f31d860ace076d422                   2  credit_card
# 79014  1a57108394169c0b47d8f876acc9ba2d                   2  credit_card
#
#        payment_installments  payment_value
# 46982                     0          58.69
# 79014                     0         129.94

# %%
df_payments['payment_installments'].value_counts().sort_values()
# Out:
# payment_installments
# 23        1
# 22        1
# 0         2
# 21        3
# 16        5
# 17        8
# 14       15
# 13       16
# 20       17
# 24       18
# 11       23
# 18       27
# 15       74
# 12      133
# 9       644
# 7      1626
# 6      3920
# 8      4268
# 5      5239
# 10     5328
# 4      7098
# 3     10461
# 2     12413
# 1     52546
# Name: count, dtype: int64

# %%
filtro = df_payments['payment_value'] == 0
df_payments[filtro]['payment_type'].value_counts()
# Out:
# payment_type
# voucher        6
# not_defined    3
# Name: count, dtype: int64

# %%
filtro = df_payments['payment_value'] == 0
filtro.sum()
# Out:
# np.int64(9)

# %%
filtro = df_payments['order_id'] == 'fa65dad1b0e818e3ccc5cb0e39231352'
df_payments[filtro].sort_values('payment_sequential')
# Out:
#                                 order_id  payment_sequential payment_type  \
# 14321   fa65dad1b0e818e3ccc5cb0e39231352                   1      voucher
# 23074   fa65dad1b0e818e3ccc5cb0e39231352                   2      voucher
# 65641   fa65dad1b0e818e3ccc5cb0e39231352                   3      voucher
# 9985    fa65dad1b0e818e3ccc5cb0e39231352                   4      voucher
# 28330   fa65dad1b0e818e3ccc5cb0e39231352                   5      voucher
# 29648   fa65dad1b0e818e3ccc5cb0e39231352                   6      voucher
# 82593   fa65dad1b0e818e3ccc5cb0e39231352                   7      voucher
# 68853   fa65dad1b0e818e3ccc5cb0e39231352                   8      voucher
# 17274   fa65dad1b0e818e3ccc5cb0e39231352                   9      voucher
# 19565   fa65dad1b0e818e3ccc5cb0e39231352                  10      voucher
# 32519   fa65dad1b0e818e3ccc5cb0e39231352                  11      voucher
# 73537   fa65dad1b0e818e3ccc5cb0e39231352                  12      voucher
# ...

# %%
df_payments['order_id'].value_counts()
# Out:
# order_id
# fa65dad1b0e818e3ccc5cb0e39231352    29
# ccf804e764ed5650cd8759557269dc13    26
# 285c2e15bebd4ac83635ccc563dc71f4    22
# 895ab968e7bb0d5659d16cd74cd1650c    21
# fedcd9f7ccdc8cba3a18defedd1a5547    19
#                                     ..
# 6d2a30c9b7dcee3ed507dc9a601f99e7     1
# a7737f6d9208dd56ea498a322ed3c37f     1
# 646e62df54f3e236eb6d5ff3b31429b8     1
# e115da7a49ec2acf622e1f31da65cfb9     1
# 28bbae6599b09d39ca406b747b6632b1     1
# Name: count, Length: 99440, dtype: int64

# %%
df_payments['order_id'].nunique()
# Out:
# 99440

# %%
df_payments.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
df_payments.dtypes
# Out:
# order_id                 object
# payment_sequential        int64
# payment_type             object
# payment_installments      int64
# payment_value           float64
# dtype: object

# %%
df_payments.columns
# Out:
# Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='object')

# %%
df_payments.shape
# Out:
# (103886, 5)

# %%
df_payments = pd.read_csv("../data/olist_order_payments_dataset.csv")
df_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# ### Analisando tradução...

# %%
df_products_complete['product_category_name_english'].isna().sum()
# Out:
# np.int64(610)

# %%
df_products_complete.loc[
    df_products_complete['product_category_name'] == 'portateis_cozinha_e_preparadores_de_alimentos',
    'product_category_name_english'
]
# Out:
# 5821     kitchen_portables_food_preparers
# 7325     kitchen_portables_food_preparers
# 8819     kitchen_portables_food_preparers
# 11039    kitchen_portables_food_preparers
# 14266    kitchen_portables_food_preparers
# 16182    kitchen_portables_food_preparers
# 17800    kitchen_portables_food_preparers
# 18610    kitchen_portables_food_preparers
# 26890    kitchen_portables_food_preparers
# 29919    kitchen_portables_food_preparers
# Name: product_category_name_english, dtype: object

# %%
df_products_complete.loc[
    df_products_complete['product_category_name'] == 'portateis_cozinha_e_preparadores_de_alimentos',
    'product_category_name_english'
] = 'kitchen_portables_food_preparers'

# %%
df_products_complete.loc[
    df_products_complete['product_category_name'] == 'pc_gamer',
    'product_category_name_english'
    ]
# Out:
# 1628     pc_gamer
# 7478     pc_gamer
# 16930    pc_gamer
# Name: product_category_name_english, dtype: object

# %%
df_products_complete.loc[
    df_products_complete['product_category_name'] == 'pc_gamer',
    'product_category_name_english'
    ] = 'pc_gamer'

# %% [markdown]
# ### Na tabela em PT vemos 610 produtos com categoria NaN. Na tabela em EN, esse número sobe para 623. Isso significa que existem 13 produtos com categoria em PT que não encontaram uma correspondência na tabela em EN. Esses 13 produtos estão dentro de duas categorias: "pc_gamer" e "portateis_cozinha_e_preparadores_de_alimentos"

# %%
df_products_complete[filtro]['product_category_name'].unique()
# Out:
# array(['pc_gamer', 'portateis_cozinha_e_preparadores_de_alimentos'],
#       dtype=object)

# %%
filtro = (df_products_complete['product_category_name'].notna()) & (df_products_complete['product_category_name_english'].isna())
df_products_complete[filtro]
# Out:
#                              product_id  \
# 1628   0105b5323d24fc655f73052694dbbb3a
# 5821   6fd83eb3e0799b775e4f946bd66657c0
# 7325   5d923ead886c44b86845f69e50520c3e
# 7478   6727051471a0fc4a0e7737b57bff2549
# 8819   bed164d9d628cf0593003389c535c6e0
# 11039  1220978a08a6b29a202bc015b18250e9
# 14266  ae62bb0f95af63d64eae5f93dddea8d3
# 16182  1954739d84629e7323a4295812a3e0ec
# 16930  dbe520fb381ad695a7e1f2807d20c765
# 17800  c7a3f1a7f9eef146cc499368b578b884
# 18610  7afdd65f79f63819ff5bee328843fa37
# 26890  a4756663d007b0cd1af865754d08d968
# 29919  cb9d764f38ee4d0c00af64d5c388f837
#
#                                product_category_name  product_name_lenght  \
# 1628                                        pc_gamer                 59.0
# 5821   portateis_cozinha_e_preparadores_de_alimentos                 52.0
# 7325   portateis_cozinha_e_preparadores_de_alimentos                 58.0
# 7478                                        pc_gamer                 60.0
# ...

# %%
filtro = df_products_complete['product_category_name_english'].isna().sum()
filtro
# Out:
# np.int64(623)

# %%
df_products_complete.shape
# Out:
# (32951, 10)

# %%
df_products.shape
# Out:
# (32951, 9)

# %%
df_products_complete = pd.merge(
    df_products,
    df_category_translation,
    on='product_category_name',
    how='left'
)

df_products_complete
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
pd.merge(
    df_products,
    df_category_translation,
    on='product_category_name',
    how='left'
)
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
df_category_translation = pd.read_csv("../data/product_category_name_translation.csv")
df_category_translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# ### Analisando produtos...

# %%
df_products['product_category_name'].value_counts()
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %%
df_products['product_category_name'].nunique()
# Out:
# 73

# %%
df_products.head(5)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df_products.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
df_products.dtypes
# Out:
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object

# %%
df_products.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')

# %%
df_products.shape
# Out:
# (32951, 9)

# %%
df_products = pd.read_csv("../data/olist_products_dataset.csv")
df_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %% [markdown]
# ### Analisando pedidos...

# %%
filtro = df_items.duplicated(subset=['order_id', 'order_item_id'])
df_items[filtro]
# Out:
# Empty DataFrame
# Columns: [order_id, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value]
# Index: []

# %%
filtro = df_items['order_id'] == "8272b63d03f5f79c56e9e4120aec44ef"
df_items[filtro]
# Out:
#                                order_id  order_item_id  \
# 57297  8272b63d03f5f79c56e9e4120aec44ef              1
# 57298  8272b63d03f5f79c56e9e4120aec44ef              2
# 57299  8272b63d03f5f79c56e9e4120aec44ef              3
# 57300  8272b63d03f5f79c56e9e4120aec44ef              4
# 57301  8272b63d03f5f79c56e9e4120aec44ef              5
# 57302  8272b63d03f5f79c56e9e4120aec44ef              6
# 57303  8272b63d03f5f79c56e9e4120aec44ef              7
# 57304  8272b63d03f5f79c56e9e4120aec44ef              8
# 57305  8272b63d03f5f79c56e9e4120aec44ef              9
# 57306  8272b63d03f5f79c56e9e4120aec44ef             10
# 57307  8272b63d03f5f79c56e9e4120aec44ef             11
# 57308  8272b63d03f5f79c56e9e4120aec44ef             12
# 57309  8272b63d03f5f79c56e9e4120aec44ef             13
# 57310  8272b63d03f5f79c56e9e4120aec44ef             14
# 57311  8272b63d03f5f79c56e9e4120aec44ef             15
# 57312  8272b63d03f5f79c56e9e4120aec44ef             16
# ...

# %%
df_items['order_id'].value_counts()
# Out:
# order_id
# 8272b63d03f5f79c56e9e4120aec44ef    21
# 1b15974a0141d54e36626dca3fdc731a    20
# ab14fdcfbe524636d65ee38360e22ce8    20
# 9ef13efd6949e4573a18964dd1bbe7f5    15
# 428a2f660dc84138d969ccd69a0ab6d5    15
#                                     ..
# 5a0911d70c1f85d3bed0df1bf693a6dd     1
# 5a082b558a3798d3e36d93bfa8ca1eae     1
# 5a07264682e0b8fbb3f166edbbffc6e8     1
# 5a071192a28951b76774e5a760c8c9b7     1
# fffe41c64501cc87c801fd61db3f6244     1
# Name: count, Length: 98666, dtype: int64

# %%
df_items['order_id'].nunique()
# Out:
# 98666

# %%
df_items.head(5)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df_items.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
df_items.dtypes
# Out:
# order_id                object
# order_item_id            int64
# product_id              object
# seller_id               object
# shipping_limit_date     object
# price                  float64
# freight_value          float64
# dtype: object

# %%
df_items.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')

# %%
df_items.shape
# Out:
# (112650, 7)

# %%
df_items = pd.read_csv("../data/olist_order_items_dataset.csv")
df_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# ### Analisando os clientes...

# %%
df_customers['customer_unique_id'].nunique()
# Out:
# 96096

# %%
df_customers['customer_id'].nunique()
# Out:
# 99441

# %%
df_customers.head(5)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
df_customers.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
df_customers.dtypes
# Out:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object

# %%
df_customers.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
df_customers.shape
# Out:
# (99441, 5)

# %%
df_customers = pd.read_csv("../data/olist_customers_dataset.csv")
df_customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %% [markdown]
# ### Ao analisar os pedidos que possuem data de entrega nula por status, identificamos 8 pedidos marcados como entregues (delivered) que não possuem uma data de entrega registrada, indicando uma possível inconsistência nos dados.

# %%
filtro = (df_orders['order_status'] == 'delivered') & (df_orders['order_delivered_customer_date'].isna())
df_orders[filtro]
# Out:
#                                order_id                       customer_id  \
# 3002   2d1e2d5bf4dc7227b3bfebb81328c15f  ec05a6d8558c6455f0cbbd8a420ad34f
# 20618  f5dd62b788049ad9fc0526e3ad11a097  5e89028e024b381dc84a13a3570decb4
# 43834  2ebdfc4f15f23b91474edf87475f108e  29f0540231702fda0cfdee0a310f11aa
# 79263  e69f75a717d64fc5ecdfae42b2e8e086  cfda40ca8dd0a5d486a9635b611b398a
# 82868  0d3268bad9b086af767785e3f0fc0133  4f1d63d35fb7c8999853b2699f5c7649
# 92643  2d858f451373b04fb5c984a1cc2defaf  e08caf668d499a6d643dafd7c5cc498a
# 97647  ab7c89dc1bf4a1ead9d6ec1ec8968a84  dd1b84a7286eb4524d52af4256c0ba24
# 98038  20edc82cf5400ce95e1afacc25798b31  28c37425f1127d887d7337f284080a0f
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 3002     delivered      2017-11-28 17:44:07  2017-11-28 17:56:40
# 20618    delivered      2018-06-20 06:58:43  2018-06-20 07:19:05
# 43834    delivered      2018-07-01 17:05:11  2018-07-01 17:15:12
# ...

# %%
filtro = df_orders['order_delivered_customer_date'].isna()
df_orders[filtro]['order_status'].value_counts()
# Out:
# order_status
# shipped        1107
# canceled        619
# unavailable     609
# invoiced        314
# processing      301
# delivered         8
# created           5
# approved          2
# Name: count, dtype: int64

# %% [markdown]
# ### Exploração inicial dos pedidos

# %%
df_orders['order_status'].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
df_orders.dtypes
# Out:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %%
df_orders.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %%
df_orders = pd.read_csv("../data/olist_orders_dataset.csv")
df_orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
import pandas as pd
